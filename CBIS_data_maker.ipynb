# %% [markdown]
# ### csv로 이미지를 읽어와서, 좌표값과 클래스가 들어가있는 csv를 생성
# -> path/to/image.jpg,x1,y1,x2,y2,class_name
#
# 예:
# /data/imgs/img_001.jpg,837,346,981,456,cow
# /data/imgs/img_002.jpg,215,312,279,391,cat
# /data/imgs/img_002.jpg,22,5,89,84,bird

# %%
import pandas as pd
import cv2
import os
from glob import glob
import pydicom as dicom
import numpy as np
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
cbis_base_path = "/home/huray/data/CBIS-DDSM"
dicom_base_path = os.path.join(cbis_base_path, "dicom")

img_save_path = "/home/huray/data/CBIS-DDSM/img"

WIDTH = 1400
HEIGHT = 1750

# %%
calc_csv_files = glob("{}/csv/calc_*.csv".format(cbis_base_path))
mass_csv_files = glob("{}/csv/mass_*.csv".format(cbis_base_path))
print(calc_csv_files)
print(mass_csv_files)

## to see examples
df = pd.read_csv(mass_csv_files[1], header=0)
df.head()
# Out:
# ['/home/huray/data/CBIS-DDSM/csv/calc_case_description_train_set.csv', '/home/huray/data/CBIS-DDSM/csv/calc_case_description_test_set.csv']
# ['/home/huray/data/CBIS-DDSM/csv/mass_case_description_train_set.csv', '/home/huray/data/CBIS-DDSM/csv/mass_case_description_test_set.csv']
#   patient_id  breast_density left or right breast image view  abnormality id  \
# 0    P_00016               4                 LEFT         CC               1
# 1    P_00016               4                 LEFT        MLO               1
# 2    P_00017               2                 LEFT         CC               1
# 3    P_00017               2                 LEFT        MLO               1
# 4    P_00032               3                RIGHT         CC               1
#
#   abnormality type mass shape   mass margins  assessment  pathology  subtlety  \
# 0             mass  IRREGULAR     SPICULATED           5  MALIGNANT         5
# 1             mass  IRREGULAR     SPICULATED           5  MALIGNANT         5
# 2             mass      ROUND  CIRCUMSCRIBED           4  MALIGNANT         4
# 3             mass      ROUND    ILL_DEFINED           4  MALIGNANT         4
# 4             mass      ROUND       OBSCURED           0     BENIGN         2
#
#                                      image file path  \
# 0  Mass-Test_P_00016_LEFT_CC/1.3.6.1.4.1.9590.100...
# 1  Mass-Test_P_00016_LEFT_MLO/1.3.6.1.4.1.9590.10...
# 2  Mass-Test_P_00017_LEFT_CC/1.3.6.1.4.1.9590.100...
# 3  Mass-Test_P_00017_LEFT_MLO/1.3.6.1.4.1.9590.10...
# 4  Mass-Test_P_00032_RIGHT_CC/1.3.6.1.4.1.9590.10...
#
#                              cropped image file path  \
# 0  Mass-Test_P_00016_LEFT_CC_1/1.3.6.1.4.1.9590.1...
# 1  Mass-Test_P_00016_LEFT_MLO_1/1.3.6.1.4.1.9590....
# 2  Mass-Test_P_00017_LEFT_CC_1/1.3.6.1.4.1.9590.1...
# 3  Mass-Test_P_00017_LEFT_MLO_1/1.3.6.1.4.1.9590....
# 4  Mass-Test_P_00032_RIGHT_CC_1/1.3.6.1.4.1.9590....
#
#                                   ROI mask file path
# 0  Mass-Test_P_00016_LEFT_CC_1/1.3.6.1.4.1.9590.1...
# 1  Mass-Test_P_00016_LEFT_MLO_1/1.3.6.1.4.1.9590....
# 2  Mass-Test_P_00017_LEFT_CC_1/1.3.6.1.4.1.9590.1...
# 3  Mass-Test_P_00017_LEFT_MLO_1/1.3.6.1.4.1.9590....
# 4  Mass-Test_P_00032_RIGHT_CC_1/1.3.6.1.4.1.9590....

# %% [markdown]
# ### 이미지와 마스크를 읽어오기(마스크인지 crop된 패치인지 구분해줘야 함)

# %%
# 일단 테스트셋 하나만 가지고 할까.
# cbis_df = pd.read_csv('/home/huray/data/CBIS-DDSM/csv/mass_case_description_test_set.csv', header=0)

# cbis_df = cbis_df[:100]

train_img_path = []
train_x1 = []
train_y1 = []
train_x2 = []
train_y2 = []
train_class_name = []

test_img_path = []
test_x1 = []
test_y1 = []
test_x2 = []
test_y2 = []
test_class_name = []

errored_data_counter = 0

for csv in calc_csv_files+mass_csv_files:
    if 'calc' in csv:
        if 'train_set' in csv:
            img_sub_path = 'calc_train'
        elif 'test_set' in csv:
            img_sub_path = 'calc_test'
        else:
            raise
    elif 'mass' in csv:
        if 'train_set' in csv:
            img_sub_path = 'mass_train'
        elif 'test_set' in csv:
            img_sub_path = 'mass_test'
        else:
            raise
        
    
    cbis_df = pd.read_csv(csv, header=0)

    for i in range(len(cbis_df)):
        if 'BENIGN_WITHOUT_CALLBACK' in cbis_df['pathology']:
            continue

        # Image file path의 split[0]이 root 경로.
        mammo_relative_root_path = cbis_df['image file path'][i].split('/')[0]
        mammo_root_path = os.path.join(dicom_base_path, mammo_relative_root_path)
        mammo_dcm_path = glob(mammo_root_path + "/**/**/*.dcm")
        if len(mammo_dcm_path) == 0:
            print("NO DCM HERE!", mammo_root_path)
            errored_data_counter += 1
            continue
        mammo_dcm_path = mammo_dcm_path[0]
    #     print(mammo_dcm_path, '\n -------------------')

        mask_relative_root_path = cbis_df['ROI mask file path'][i].split('/')[0]
        mask_root_path = os.path.join(dicom_base_path, mask_relative_root_path)
        tmp_mask_dcm_path = sorted(glob(mask_root_path + "/**/**/*.dcm"))
        if len(tmp_mask_dcm_path) == 0:
            print("NO DCM HERE! ", tmp_mask_dcm_path)
            errored_data_counter += 1
            continue
        if len(tmp_mask_dcm_path) == 1:
            print("only 1 DCM in mask path:", tmp_mask_dcm_path )
            if os.path.getsize(tmp_mask_dcm_path[0])/1024/1024 >= 3 :
                mask_dcm_path = tmp_mask_dcm_path[0]
            else:
                print("NO MASK! ", tmp_mask_dcm_path)
                errored_data_counter += 1
                continue
        else: # mask와 패치가 둘 다 잘 들어있는 경우.
            for f in tmp_mask_dcm_path: # 패치와 mask가 파일 뒤섞인 경우 있으므로 사이즈 비교로 확인: 
                if os.path.getsize(tmp_mask_dcm_path[1])/1024/1024 >= 3 : # 일반적으론 000001이 mask. 얘가 5메가 이상이면 마스크인걸로.
                    mask_dcm_path = tmp_mask_dcm_path[1]
                elif os.path.getsize(tmp_mask_dcm_path[0])/1024/1024 >= 3 :
                    mask_dcm_path = tmp_mask_dcm_path[0]
                else:
                    print('both files are not bigger than 3MB')
                    raise
            
            
    #     print(tmp_mask_dcm_path, '\n -------------------')

    #     print(mask_dcm_path, '\n -------------------')


        mammo_dcm = dicom.read_file(mammo_dcm_path)
        mask_dcm = dicom.read_file(mask_dcm_path)

        try:
            mammo_arr = mammo_dcm.pixel_array
            mammo_arr = mammo_arr.astype(np.uint16)
        except AttributeError: # 종종 파일 자체가 문제가 있는 경우 있음.
            try:
                pixel_data = mammo_dcm[0x7fe0,0x0010].value # 파일 자체에 저장된 pixel_data값
                rows = mammo_dcm[0x0028, 0x0010].value # metadata로 들어있는 row
                cols = mammo_dcm[0x0028, 0x0011].value # metadata로 들어있는col

                mammo_arr = np.fromstring(pixel_data[:-1], dtype=np.uint16)
                mammo_arr = np.reshape(mammo_arr, (rows, cols))
            except ValueError:
                print('corrupted file: ' + mammo_dcm_path[:70])
                errored_data_counter += 1
                continue
            else:
                print('Attribute error" ' + mammo_dcm_path[:70])
        except:
            print('different error: ' + mammo_dcm_path[:70])
            errored_data_counter += 1
            continue

        try:
            mask_arr = mask_dcm.pixel_array
            mask_arr = mask_arr.astype(np.uint8)
        except AttributeError: # 종종 파일 자체가 문제가 있는 경우 있음.
            try:
                pixel_data = mammo_dcm[0x7fe0,0x0010].value # 파일 자체에 저장된 pixel_data값
                rows = mammo_dcm[0x0028, 0x0010].value # metadata로 들어있는 row
                cols = mammo_dcm[0x0028, 0x0011].value # metadata로 들어있는col

                mask_arr = np.fromstring(pixel_data[:-1], dtype=np.uint8)
                mask_arr = np.reshape(mask_arr, (rows, cols, -1))
            except ValueError:
                print('corrupted file: ' + mask_dcm_path[:70])
                errored_data_counter += 1
                continue
            else:
                print('Attribute error" ' + mask_dcm_path[:70])
        except:
            print('different error: ' + mask_dcm_path[:70])
            abnormal += 1
            continue

        # 논문 내용대로 0~255로 리스케일.
        mammo_arr_final = (mammo_arr - np.amin(mammo_arr))/(np.amax(mammo_arr) - np.amin(mammo_arr)) * 255
        mammo_arr_final = mammo_arr_final.astype(np.uint8)
        mammo_arr_final = cv2.resize(mammo_arr_final, (WIDTH, HEIGHT))
        mammo_arr_final = np.asarray(np.dstack((mammo_arr_final, mammo_arr_final, mammo_arr_final)), dtype=np.uint8)

        mask_arr = cv2.resize(mask_arr, (WIDTH, HEIGHT))
        mask_arr[mask_arr >= 1] = 255

        ret, thresh = cv2.threshold(mask_arr, 127, 255, cv2.THRESH_BINARY)
        image, contours, hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

        if len(contours) > 1: # 혹시 annotation이 끊어져있을 경우를 대비.
            contours = [max(contours, key=len)]

        cnt = contours[0]

        x,y,w,h = cv2.boundingRect(cnt) # 좌상단 꼭지점과 거기서부터의 가로길이 w, 세로길이 h가 return 됨.
    #     print(x,y,w,h)

        # 제대로 bounding box 만들고있는지 체크하기 위한 코드
    #     mask_arr_color = cv2.cvtColor(mask_arr, cv2.COLOR_GRAY2BGR)
    #     cv2.rectangle(mask_arr_color, (x, y), (x+w, y+h), (0,0,255), 3)

    #     plt.imshow(mask_arr_color)
    #     plt.title('image')
    #     plt.show() 



        #### mammo를 이미지로 저장
        mammo_jpg_path = os.path.join(img_save_path, img_sub_path, mask_dcm_path.split("/")[6]+".jpg")
        cv2.imwrite(mammo_jpg_path, mammo_arr_final)
        
        if 'train_set' in csv:
            train_img_path.append(mammo_jpg_path)
            train_x1.append(x)
            train_y1.append(y)
            train_x2.append(x+w)
            train_y2.append(y+h)
#             train_class_name.append(cbis_df['pathology'][i][0] + '_' + cbis_df['abnormality type'][i][:4])
            train_class_name.append(cbis_df['pathology'][i])
            
        elif 'test_set' in csv:
            test_img_path.append(mammo_jpg_path)
            test_x1.append(x)
            test_y1.append(y)
            test_x2.append(x+w)
            test_y2.append(y+h)
#             test_class_name.append(cbis_df['pathology'][i][0] + '_' + cbis_df['abnormality type'][i][:4])
            test_class_name.append(cbis_df['pathology'][i])
            
        else:
            raise
# Out:
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00011_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00016_LEFT_MLO_2/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00019_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00024_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00034_RIGHT_MLO_2/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00049_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00105_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00151_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00162_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00181_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00182_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00185_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00188_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00196_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00201_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00245_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00251_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00255_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00255_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00270_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00274_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00276_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00276_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00293_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00293_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00318_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00321_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00336_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00357_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00400_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00445_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00458_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00473_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00473_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00474_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00484_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00491_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00502_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00508_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00508_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00551_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00556_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00574_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00578_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00583_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00595_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00595_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00609_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00624_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00625_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00647_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00658_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00658_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00735_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00787_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00806_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00832_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00835_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00846_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00854_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00854_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00866_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00880_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00897_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00912_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00930_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00933_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00945_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00954_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00954_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00956_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00965_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_00965_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01010_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01016_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01045_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01056_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01063_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01094_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01100_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01100_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01126_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01137_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01137_LEFT_MLO_1/1.3.
# NO DCM HERE! /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01161_LEFT_CC
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01172_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01193_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01249_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01259_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01264_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01337_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01339_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01342_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01369_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01370_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01387_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01422_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01424_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01446_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01459_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01497_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01524_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01524_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01548_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01549_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01571_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01575_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01605_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01609_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01647_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01655_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01655_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01659_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01660_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01679_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01679_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01723_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01729_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01730_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01736_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01736_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01736_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01736_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01750_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01756_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01767_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01847_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_01856_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02105_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02154_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02154_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02190_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02195_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02232_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02259_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02270_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02285_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02313_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02318_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02348_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02368_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02400_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02424_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02424_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02437_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02442_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02459_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02460_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02468_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02522_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02559_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02572_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Training_P_02584_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_00100_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_00100_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_00141_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_00180_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_00497_LEFT_CC_1/1.3.6.1.4
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_00608_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_00646_LEFT_CC_1/1.3.6.1.4
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_00649_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_00774_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_00774_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_00811_LEFT_CC_1/1.3.6.1.4
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_00827_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_00827_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_00919_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01092_LEFT_CC_1/1.3.6.1.4
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01148_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01217_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01308_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01320_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01353_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01414_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01415_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01419_LEFT_CC_1/1.3.6.1.4
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01523_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01534_LEFT_CC_1/1.3.6.1.4
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01535_LEFT_CC_1/1.3.6.1.4
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01536_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01711_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01728_LEFT_CC_1/1.3.6.1.4
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01752_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01820_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01842_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01845_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01845_RIGHT_MLO_2/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01861_LEFT_CC_1/1.3.6.1.4
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_01872_LEFT_CC_1/1.3.6.1.4
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_02153_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_02198_LEFT_CC_1/1.3.6.1.4
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_02275_LEFT_CC_1/1.3.6.1.4
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_02275_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_02418_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_02420_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_02420_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_02464_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Calc-Test_P_02501_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00004_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00023_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00034_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00058_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00074_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00074_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00221_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00248_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00273_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00289_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00304_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00333_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00333_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00348_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00348_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00354_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00356_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00370_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00370_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00396_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00406_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00414_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00427_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00437_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00440_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00444_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00454_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00468_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00492_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00496_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00526_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00526_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00543_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00566_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00605_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00644_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00661_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00694_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00720_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00764_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00782_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00803_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00810_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00815_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00815_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00816_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00826_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00831_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00898_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00913_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00939_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00995_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_00996_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01031_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01057_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01070_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01093_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01115_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01118_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01124_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01164_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01165_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01171_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01173_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01206_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01215_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01230_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01258_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01264_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01268_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01271_RIGHT_CC_1/1.3.
# only 1 DCM in mask path: ['/home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01274_RIGHT_MLO_1/1.3.6.1.4.1.9590.100.1.2.315387872913738088714589441552174734377/1.3.6.1.4.1.9590.100.1.2.196398184912033488622945934210693879222/000000.dcm']
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01299_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01324_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01327_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01355_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01360_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01360_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01363_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01367_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01371_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01371_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01379_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01394_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01394_LEFT_CC_2/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01394_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01394_LEFT_MLO_2/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01423_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01433_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01439_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01442_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01445_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01474_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01485_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01485_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01495_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01503_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01504_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01508_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01509_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01509_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01532_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01557_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01560_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01581_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01583_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01611_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01612_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01613_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01619_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01637_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01638_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01641_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01669_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01689_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01715_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01745_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01757_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01757_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01799_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01805_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01816_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01816_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01829_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01850_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01876_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01877_LEFT_CC_1/1.3.6
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01886_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01887_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01981_RIGHT_CC_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01981_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_01983_LEFT_MLO_1/1.3.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Training_P_02079_RIGHT_MLO_1/1.3
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00016_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00066_LEFT_CC_1/1.3.6.1.4
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00118_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00126_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00126_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00145_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00171_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00203_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00209_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00358_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00381_LEFT_CC_1/1.3.6.1.4
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00391_LEFT_CC_1/1.3.6.1.4
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00391_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00391_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00498_LEFT_CC_1/1.3.6.1.4
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00498_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00615_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00656_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00758_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00813_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00837_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00875_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00922_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_00962_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01110_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01114_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01167_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01187_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01210_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01257_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01322_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01323_LEFT_CC_1/1.3.6.1.4
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01323_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01347_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01347_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01348_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01510_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01512_LEFT_CC_1/1.3.6.1.4
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01518_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01534_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01539_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01558_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01578_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01590_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01605_LEFT_CC_2/1.3.6.1.4
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01614_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01640_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01661_LEFT_CC_1/1.3.6.1.4
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01661_LEFT_MLO_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01765_RIGHT_CC_1/1.3.6.1.
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01765_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01807_RIGHT_MLO_1/1.3.6.1
# corrupted file: /home/huray/data/CBIS-DDSM/dicom/Mass-Test_P_01865_LEFT_MLO_1/1.3.6.1.

# %%
train_data_df = pd.DataFrame({'img_path':train_img_path, 'x1':train_x1, 'y1':train_y1, 'x2':train_x2, 'y2':train_y2, 'class_name':train_class_name})
train_data_df = train_data_df[['img_path', 'x1', 'y1', 'x2', 'y2', 'class_name']]

test_data_df = pd.DataFrame({'img_path':test_img_path, 'x1':test_x1, 'y1':test_y1, 'x2':test_x2, 'y2':test_y2, 'class_name':test_class_name})
test_data_df = test_data_df[['img_path', 'x1', 'y1', 'x2', 'y2', 'class_name']]

whole_data_df = train_data_df.append(test_data_df, ignore_index=True)

print('DATA COUNTS: ', len(train_data_df)+len(test_data_df))
print('Train data COUNTS: ', len(train_data_df))
print('Test data COUNTS: ', len(test_data_df))
# Out:
# DATA COUNTS:  3185
# Train data COUNTS:  2579
# Test data COUNTS:  606

# %%
train_data_df.to_csv('/home/huray/data/CBIS-DDSM/img/data_train.csv', header=False, index=False)
test_data_df.to_csv('/home/huray/data/CBIS-DDSM/img/data_test.csv', header=False, index=False)
whole_data_df.to_csv('/home/huray/data/CBIS-DDSM/img/data_whole.csv', header=False, index=False)

# %%
print(errored_data_counter)
# Out:
# 383
